# %%
from google.colab.patches import cv2_imshow
import cv2
img=cv2.imread('cars.jpeg')
cv2.rectangle(img,(100,300),(450,500),color=(200,0,0),thickness=3)
cv2.rectangle(img,(500,300),(870,500),color=(0,255,0),thickness=3)
img_resize=cv2.resize(img,(400,300))
cv2_imshow(img_resize)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300>
